# %%
import Utils.General
import os

URL = "https://www.youtube.com/watch?v=zpr0hQ4o16M&list=PL6xNyHIAgJG5h_4zWWLzwynxqOnMxiUVa&index=1"
Utils.General.BASE_PATH = "videos\\Self Improvement"
shorts_paths_file = os.path.join(Utils.General.BASE_PATH,'shorts_paths.json')

# %%
videos_data = Utils.General.DownloadAndProcessFromURL(URL)

# %%
import json
videos_data = json.loads(open(os.path.join(Utils.General.BASE_PATH,"videos_data.json")).read())

# %%
shorts_paths = Utils.General.VideosDataToShorts(videos_data, shorts_paths_file)
# Out:
# 1/1
#     1/24
#     Blurred And Centered
# 100%|██████████| 22/22 [00:08<00:00,  2.68it/s]
#     Generated Text Clips
#     Combined Video And Text Clip
#     Combined Video And Audio
# Moviepy - Building video videos\Self Improvement\zpr0hQ4o16M\shorts\0.mp4.
# MoviePy - Writing audio in 0TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video videos\Self Improvement\zpr0hQ4o16M\shorts\0.mp4
# Moviepy - Done !
# Moviepy - video ready videos\Self Improvement\zpr0hQ4o16M\shorts\0.mp4
#     2/24
#     Blurred And Centered
# 100%|██████████| 130/130 [00:53<00:00,  2.41it/s]
#     Generated Text Clips
#     Combined Video And Text Clip
#     Combined Video And Audio
# Moviepy - Building video videos\Self Improvement\zpr0hQ4o16M\shorts\1.mp4.
# MoviePy - Writing audio in 1TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video videos\Self Improvement\zpr0hQ4o16M\shorts\1.mp4
# t:  78%|███████▊  | 1626/2080 [22:37<05:54,  1.28it/s, now=None]
